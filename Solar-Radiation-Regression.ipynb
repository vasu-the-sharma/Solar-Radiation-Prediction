# %% [markdown]
# # Solar Radiation Regression using XGBoost & Optuna

# %% [markdown]
# Dataset URL: https://www.kaggle.com/dronio/SolarEnergy

# %% [markdown]
# ## IMPORTING THE LIBRARIES

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
import xgboost as xgb
import optuna
from sklearn.metrics import r2_score

# %% [markdown]
# ## IMPORTING THE DATASET

# %%
data = pd.read_csv("SolarPrediction.csv")

# %%
data
# Out:
#          UNIXTime                   Data      Time  Radiation  Temperature  \
# 0      1475229326  9/29/2016 12:00:00 AM  23:55:26       1.21           48
# 1      1475229023  9/29/2016 12:00:00 AM  23:50:23       1.21           48
# 2      1475228726  9/29/2016 12:00:00 AM  23:45:26       1.23           48
# 3      1475228421  9/29/2016 12:00:00 AM  23:40:21       1.21           48
# 4      1475228124  9/29/2016 12:00:00 AM  23:35:24       1.17           48
# ...           ...                    ...       ...        ...          ...
# 32681  1480587604  12/1/2016 12:00:00 AM  00:20:04       1.22           44
# 32682  1480587301  12/1/2016 12:00:00 AM  00:15:01       1.17           44
# 32683  1480587001  12/1/2016 12:00:00 AM  00:10:01       1.20           44
# 32684  1480586702  12/1/2016 12:00:00 AM  00:05:02       1.23           44
# 32685  1480586402  12/1/2016 12:00:00 AM  00:00:02       1.20           44
#
#        Pressure  Humidity  WindDirection(Degrees)  Speed TimeSunRise  \
# 0         30.46        59                  177.39   5.62    06:13:00
# 1         30.46        58                  176.78   3.37    06:13:00
# 2         30.46        57                  158.75   3.37    06:13:00
# 3         30.46        60                  137.71   3.37    06:13:00
# 4         30.46        62                  104.95   5.62    06:13:00
# ...         ...       ...                     ...    ...         ...
# 32681     30.43       102                  145.42   6.75    06:41:00
# 32682     30.42       102                  117.78   6.75    06:41:00
# 32683     30.42       102                  145.19   9.00    06:41:00
# 32684     30.42       101                  164.19   7.87    06:41:00
# 32685     30.43       101                   83.59   3.37    06:41:00
#
#       TimeSunSet
# 0       18:13:00
# 1       18:13:00
# 2       18:13:00
# 3       18:13:00
# 4       18:13:00
# ...          ...
# 32681   17:42:00
# 32682   17:42:00
# 32683   17:42:00
# 32684   17:42:00
# 32685   17:42:00
#
# [32686 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32686 entries, 0 to 32685
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   UNIXTime                32686 non-null  int64
#  1   Data                    32686 non-null  object
#  2   Time                    32686 non-null  object
#  3   Radiation               32686 non-null  float64
#  4   Temperature             32686 non-null  int64
#  5   Pressure                32686 non-null  float64
#  6   Humidity                32686 non-null  int64
#  7   WindDirection(Degrees)  32686 non-null  float64
#  8   Speed                   32686 non-null  float64
#  9   TimeSunRise             32686 non-null  object
#  10  TimeSunSet              32686 non-null  object
# dtypes: float64(4), int64(3), object(4)
# memory usage: 2.7+ MB

# %%
print("Total missing values: ", data.isnull().sum().sum())
# Out:
# Total missing values:  0

# %% [markdown]
# ## FEATURE ENGINEERING

# %%
data
# Out:
#          UNIXTime                   Data      Time  Radiation  Temperature  \
# 0      1475229326  9/29/2016 12:00:00 AM  23:55:26       1.21           48
# 1      1475229023  9/29/2016 12:00:00 AM  23:50:23       1.21           48
# 2      1475228726  9/29/2016 12:00:00 AM  23:45:26       1.23           48
# 3      1475228421  9/29/2016 12:00:00 AM  23:40:21       1.21           48
# 4      1475228124  9/29/2016 12:00:00 AM  23:35:24       1.17           48
# ...           ...                    ...       ...        ...          ...
# 32681  1480587604  12/1/2016 12:00:00 AM  00:20:04       1.22           44
# 32682  1480587301  12/1/2016 12:00:00 AM  00:15:01       1.17           44
# 32683  1480587001  12/1/2016 12:00:00 AM  00:10:01       1.20           44
# 32684  1480586702  12/1/2016 12:00:00 AM  00:05:02       1.23           44
# 32685  1480586402  12/1/2016 12:00:00 AM  00:00:02       1.20           44
#
#        Pressure  Humidity  WindDirection(Degrees)  Speed TimeSunRise  \
# 0         30.46        59                  177.39   5.62    06:13:00
# 1         30.46        58                  176.78   3.37    06:13:00
# 2         30.46        57                  158.75   3.37    06:13:00
# 3         30.46        60                  137.71   3.37    06:13:00
# 4         30.46        62                  104.95   5.62    06:13:00
# ...         ...       ...                     ...    ...         ...
# 32681     30.43       102                  145.42   6.75    06:41:00
# 32682     30.42       102                  117.78   6.75    06:41:00
# 32683     30.42       102                  145.19   9.00    06:41:00
# 32684     30.42       101                  164.19   7.87    06:41:00
# 32685     30.43       101                   83.59   3.37    06:41:00
#
#       TimeSunSet
# 0       18:13:00
# 1       18:13:00
# 2       18:13:00
# 3       18:13:00
# 4       18:13:00
# ...          ...
# 32681   17:42:00
# 32682   17:42:00
# 32683   17:42:00
# 32684   17:42:00
# 32685   17:42:00
#
# [32686 rows x 11 columns]

# %%
import re

# %%
data['Month'] = data['Data'].apply(lambda x: re.search(r'^\d+', x).group(0)).astype(np.int)
data['Day'] = data['Data'].apply(lambda x: re.search(r'(?<=\/)\d+(?=\/)', x).group(0)).astype(np.int)
data['Year'] = data['Data'].apply(lambda x: re.search(r'(?<=\/)\d+(?=\s)', x).group(0)).astype(np.int)

data = data.drop('Data', axis=1)

# %%
data
# Out:
#          UNIXTime      Time  Radiation  Temperature  Pressure  Humidity  \
# 0      1475229326  23:55:26       1.21           48     30.46        59
# 1      1475229023  23:50:23       1.21           48     30.46        58
# 2      1475228726  23:45:26       1.23           48     30.46        57
# 3      1475228421  23:40:21       1.21           48     30.46        60
# 4      1475228124  23:35:24       1.17           48     30.46        62
# ...           ...       ...        ...          ...       ...       ...
# 32681  1480587604  00:20:04       1.22           44     30.43       102
# 32682  1480587301  00:15:01       1.17           44     30.42       102
# 32683  1480587001  00:10:01       1.20           44     30.42       102
# 32684  1480586702  00:05:02       1.23           44     30.42       101
# 32685  1480586402  00:00:02       1.20           44     30.43       101
#
#        WindDirection(Degrees)  Speed TimeSunRise TimeSunSet  Month  Day  Year
# 0                      177.39   5.62    06:13:00   18:13:00      9   29  2016
# 1                      176.78   3.37    06:13:00   18:13:00      9   29  2016
# 2                      158.75   3.37    06:13:00   18:13:00      9   29  2016
# 3                      137.71   3.37    06:13:00   18:13:00      9   29  2016
# 4                      104.95   5.62    06:13:00   18:13:00      9   29  2016
# ...                       ...    ...         ...        ...    ...  ...   ...
# 32681                  145.42   6.75    06:41:00   17:42:00     12    1  2016
# 32682                  117.78   6.75    06:41:00   17:42:00     12    1  2016
# 32683                  145.19   9.00    06:41:00   17:42:00     12    1  2016
# 32684                  164.19   7.87    06:41:00   17:42:00     12    1  2016
# 32685                   83.59   3.37    06:41:00   17:42:00     12    1  2016
#
# [32686 rows x 13 columns]

# %%
data['Hour'] = data['Time'].apply(lambda x: re.search(r'^\d+', x).group(0)).astype(np.int)
data['Minute'] = data['Time'].apply(lambda x: re.search(r'(?<=:)\d+(?=:)', x).group(0)).astype(np.int)
data['Second'] = data['Time'].apply(lambda x: re.search(r'\d+$', x).group(0)).astype(np.int)

data = data.drop('Time', axis=1)

# %%
data
# Out:
#          UNIXTime  Radiation  Temperature  Pressure  Humidity  \
# 0      1475229326       1.21           48     30.46        59
# 1      1475229023       1.21           48     30.46        58
# 2      1475228726       1.23           48     30.46        57
# 3      1475228421       1.21           48     30.46        60
# 4      1475228124       1.17           48     30.46        62
# ...           ...        ...          ...       ...       ...
# 32681  1480587604       1.22           44     30.43       102
# 32682  1480587301       1.17           44     30.42       102
# 32683  1480587001       1.20           44     30.42       102
# 32684  1480586702       1.23           44     30.42       101
# 32685  1480586402       1.20           44     30.43       101
#
#        WindDirection(Degrees)  Speed TimeSunRise TimeSunSet  Month  Day  Year  \
# 0                      177.39   5.62    06:13:00   18:13:00      9   29  2016
# 1                      176.78   3.37    06:13:00   18:13:00      9   29  2016
# 2                      158.75   3.37    06:13:00   18:13:00      9   29  2016
# 3                      137.71   3.37    06:13:00   18:13:00      9   29  2016
# 4                      104.95   5.62    06:13:00   18:13:00      9   29  2016
# ...                       ...    ...         ...        ...    ...  ...   ...
# 32681                  145.42   6.75    06:41:00   17:42:00     12    1  2016
# 32682                  117.78   6.75    06:41:00   17:42:00     12    1  2016
# 32683                  145.19   9.00    06:41:00   17:42:00     12    1  2016
# 32684                  164.19   7.87    06:41:00   17:42:00     12    1  2016
# 32685                   83.59   3.37    06:41:00   17:42:00     12    1  2016
#
#        Hour  Minute  Second
# 0        23      55      26
# 1        23      50      23
# 2        23      45      26
# 3        23      40      21
# 4        23      35      24
# ...     ...     ...     ...
# 32681     0      20       4
# 32682     0      15       1
# 32683     0      10       1
# 32684     0       5       2
# 32685     0       0       2
#
# [32686 rows x 15 columns]

# %%
data['SunriseHour'] = data['TimeSunRise'].apply(lambda x: re.search(r'^\d+', x).group(0)).astype(np.int)
data['SunriseMinute'] = data['TimeSunRise'].apply(lambda x: re.search(r'(?<=:)\d+(?=:)', x).group(0)).astype(np.int)

data['SunsetHour'] = data['TimeSunSet'].apply(lambda x: re.search(r'^\d+', x).group(0)).astype(np.int)
data['SunsetMinute'] = data['TimeSunSet'].apply(lambda x: re.search(r'(?<=:)\d+(?=:)', x).group(0)).astype(np.int)

data = data.drop(['TimeSunRise', 'TimeSunSet'], axis=1)

# %%
data
# Out:
#          UNIXTime  Radiation  Temperature  Pressure  Humidity  \
# 0      1475229326       1.21           48     30.46        59
# 1      1475229023       1.21           48     30.46        58
# 2      1475228726       1.23           48     30.46        57
# 3      1475228421       1.21           48     30.46        60
# 4      1475228124       1.17           48     30.46        62
# ...           ...        ...          ...       ...       ...
# 32681  1480587604       1.22           44     30.43       102
# 32682  1480587301       1.17           44     30.42       102
# 32683  1480587001       1.20           44     30.42       102
# 32684  1480586702       1.23           44     30.42       101
# 32685  1480586402       1.20           44     30.43       101
#
#        WindDirection(Degrees)  Speed  Month  Day  Year  Hour  Minute  Second  \
# 0                      177.39   5.62      9   29  2016    23      55      26
# 1                      176.78   3.37      9   29  2016    23      50      23
# 2                      158.75   3.37      9   29  2016    23      45      26
# 3                      137.71   3.37      9   29  2016    23      40      21
# 4                      104.95   5.62      9   29  2016    23      35      24
# ...                       ...    ...    ...  ...   ...   ...     ...     ...
# 32681                  145.42   6.75     12    1  2016     0      20       4
# 32682                  117.78   6.75     12    1  2016     0      15       1
# 32683                  145.19   9.00     12    1  2016     0      10       1
# 32684                  164.19   7.87     12    1  2016     0       5       2
# 32685                   83.59   3.37     12    1  2016     0       0       2
#
#        SunriseHour  SunriseMinute  SunsetHour  SunsetMinute
# 0                6             13          18            13
# 1                6             13          18            13
# 2                6             13          18            13
# 3                6             13          18            13
# 4                6             13          18            13
# ...            ...            ...         ...           ...
# 32681            6             41          17            42
# 32682            6             41          17            42
# 32683            6             41          17            42
# 32684            6             41          17            42
# 32685            6             41          17            42
#
# [32686 rows x 17 columns]

# %%
data.dtypes
# Out:
# UNIXTime                    int64
# Radiation                 float64
# Temperature                 int64
# Pressure                  float64
# Humidity                    int64
# WindDirection(Degrees)    float64
# Speed                     float64
# Month                       int32
# Day                         int32
# Year                        int32
# Hour                        int32
# Minute                      int32
# Second                      int32
# SunriseHour                 int32
# SunriseMinute               int32
# SunsetHour                  int32
# SunsetMinute                int32
# dtype: object

# %%
data['Year'].unique()
# Out:
# array([2016])

# %%
data['SunriseHour'].unique()
# Out:
# array([6])

# %%
data = data.drop(['Year', 'SunriseHour'], axis=1)

# %% [markdown]
# ## SPLITTING/SCALING

# %%
y=data['Radiation'].copy()
X=data.drop('Radiation', axis=1).copy()

# %%
scaler = StandardScaler()

# %%
X=scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=100)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, train_size=0.8, random_state=200)

# %%
dtrain = xgb.DMatrix(X_train, label=y_train)
dval = xgb.DMatrix(X_val, label=y_val)
dtest = xgb.DMatrix(X_test, label=y_test)

# %% [markdown]
# ## HYPERPARAMTER SEARCH

# %%
def get_model_rmse(params):
    model = xgb.train(params, dtrain, num_boost_round=100, evals=[(dval, 'eval')], early_stopping_rounds=10, verbose_eval=0)
    results = model.eval(dval)
    rmse = np.float(re.search(r'[\d.]+$', results).group(0))
    return rmse

# %%
def objective(trial):
    learning_rate = trial.suggest_loguniform('learning_rate', 0.00001, 10.0)
    max_depth = trial.suggest_int('max_depth', 4, 8)
    l1_reg = trial.suggest_loguniform('l1_reg', 0.00001, 10.0)
    l2_reg = trial.suggest_loguniform('l2_reg', 0.00001, 10.0)
    
    params = {'learning_rate': learning_rate, 'max_depth': max_depth, 'alpha': l1_reg, 'lambda': l2_reg}
    
    return get_model_rmse(params)

# %%
study = optuna.create_study()
study.optimize(objective, n_trials=100, show_progress_bar=True)
# Out:
# [I 2020-11-11 21:06:24,682] A new study created in memory with name: no-name-e100ca84-e1a8-4543-a11c-84ef69f5b299
# C:\Users\vasut\anaconda3\lib\site-packages\optuna\progress_bar.py:47: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#   self._init_valid()
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
. Best is trial 33 with value: 83.299904.
# [I 2020-11-11 21:08:34,182] Trial 98 finished with value: 85.623604 and parameters: {'learning_rate': 0.44743128127648957, 'max_depth': 8, 'l1_reg': 0.00033874177070805807, 'l2_reg': 6.117179216601161}. Best is trial 33 with value: 83.299904.
# [I 2020-11-11 21:08:35,793] Trial 99 finished with value: 84.572418 and parameters: {'learning_rate': 0.21838791505243602, 'max_depth': 8, 'l1_reg': 0.0005469934222281618, 'l2_reg': 2.449526863290382}. Best is trial 33 with value: 83.299904.

# %%
best_params = study.best_params
best_params
# Out:
# {'learning_rate': 0.11058195124847281,
#  'max_depth': 8,
#  'l1_reg': 1.056385504583485e-05,
#  'l2_reg': 0.016145187553476003}

# %%
model = xgb.train(best_params, dtrain, num_boost_round=10000, evals=[(dval, 'eval')], early_stopping_rounds=10)
# Out:
# [21:08:59] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\learner.cc:328:
# Parameters: { l1_reg, l2_reg } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	eval-rmse:343.31421
# Will train until eval-rmse hasn't improved in 10 rounds.
# [1]	eval-rmse:309.60764
# [2]	eval-rmse:279.95245
# [3]	eval-rmse:253.93411
# [4]	eval-rmse:231.15678
# [5]	eval-rmse:211.01465
# [6]	eval-rmse:193.47096
# [7]	eval-rmse:178.10925
# [8]	eval-rmse:164.97127
# [9]	eval-rmse:153.45482
# [10]	eval-rmse:143.83037
# [11]	eval-rmse:135.18835
# [12]	eval-rmse:127.81662
# [13]	eval-rmse:121.52767
# [14]	eval-rmse:116.27657
# [15]	eval-rmse:111.88757
# [16]	eval-rmse:107.98895
# [17]	eval-rmse:104.73846
# [18]	eval-rmse:102.20950
# [19]	eval-rmse:99.81844
# [20]	eval-rmse:97.89329
# [21]	eval-rmse:96.28895
# [22]	eval-rmse:94.91874
# [23]	eval-rmse:93.62908
# [24]	eval-rmse:92.52450
# [25]	eval-rmse:91.52024
# [26]	eval-rmse:90.77256
# [27]	eval-rmse:89.98038
# [28]	eval-rmse:89.33646
# [29]	eval-rmse:88.76683
# [30]	eval-rmse:88.36211
# [31]	eval-rmse:87.96706
# [32]	eval-rmse:87.70815
# [33]	eval-rmse:87.45480
# [34]	eval-rmse:87.30157
# [35]	eval-rmse:87.11340
# [36]	eval-rmse:86.96081
# [37]	eval-rmse:86.62494
# [38]	eval-rmse:86.40403
# [39]	eval-rmse:86.30116
# [40]	eval-rmse:86.27879
# [41]	eval-rmse:86.13043
# [42]	eval-rmse:85.97447
# [43]	eval-rmse:85.84738
# [44]	eval-rmse:85.87071
# [45]	eval-rmse:85.72895
# [46]	eval-rmse:85.73154
# [47]	eval-rmse:85.74522
# [48]	eval-rmse:85.67071
# [49]	eval-rmse:85.65501
# [50]	eval-rmse:85.62761
# [51]	eval-rmse:85.49037
# [52]	eval-rmse:85.28001
# [53]	eval-rmse:85.27861
# [54]	eval-rmse:85.14169
# [55]	eval-rmse:85.02368
# [56]	eval-rmse:84.98159
# [57]	eval-rmse:84.91757
# [58]	eval-rmse:84.85718
# [59]	eval-rmse:84.77269
# [60]	eval-rmse:84.72276
# [61]	eval-rmse:84.65898
# [62]	eval-rmse:84.62708
# [63]	eval-rmse:84.52015
# [64]	eval-rmse:84.52402
# [65]	eval-rmse:84.53387
# [66]	eval-rmse:84.55981
# [67]	eval-rmse:84.47416
# [68]	eval-rmse:84.46680
# [69]	eval-rmse:84.42993
# [70]	eval-rmse:84.28752
# [71]	eval-rmse:84.28595
# [72]	eval-rmse:84.22961
# [73]	eval-rmse:84.24432
# [74]	eval-rmse:84.22224
# [75]	eval-rmse:84.18896
# [76]	eval-rmse:84.16137
# [77]	eval-rmse:84.14916
# [78]	eval-rmse:84.17037
# [79]	eval-rmse:84.23262
# [80]	eval-rmse:84.16392
# [81]	eval-rmse:84.15978
# [82]	eval-rmse:84.16530
# [83]	eval-rmse:84.16468
# [84]	eval-rmse:84.13731
# [85]	eval-rmse:84.11053
# [86]	eval-rmse:84.07986
# [87]	eval-rmse:84.08638
# [88]	eval-rmse:84.04844
# [89]	eval-rmse:84.05761
# [90]	eval-rmse:84.03041
# [91]	eval-rmse:83.97608
# [92]	eval-rmse:83.99778
# [93]	eval-rmse:84.01511
# [94]	eval-rmse:84.00530
# [95]	eval-rmse:83.98564
# [96]	eval-rmse:83.92101
# [97]	eval-rmse:83.88662
# [98]	eval-rmse:83.89203
# [99]	eval-rmse:83.90142
# [100]	eval-rmse:83.89706
# [101]	eval-rmse:83.91213
# [102]	eval-rmse:83.88628
# [103]	eval-rmse:83.85936
# [104]	eval-rmse:83.84373
# [105]	eval-rmse:83.85620
# [106]	eval-rmse:83.93852
# [107]	eval-rmse:83.95905
# [108]	eval-rmse:83.92616
# [109]	eval-rmse:83.90401
# [110]	eval-rmse:83.85563
# [111]	eval-rmse:83.88866
# [112]	eval-rmse:83.85047
# [113]	eval-rmse:83.83812
# [114]	eval-rmse:83.79658
# [115]	eval-rmse:83.77536
# [116]	eval-rmse:83.73302
# [117]	eval-rmse:83.69602
# [118]	eval-rmse:83.72414
# [119]	eval-rmse:83.70136
# [120]	eval-rmse:83.69802
# [121]	eval-rmse:83.70856
# [122]	eval-rmse:83.72405
# [123]	eval-rmse:83.72501
# [124]	eval-rmse:83.68811
# [125]	eval-rmse:83.66324
# [126]	eval-rmse:83.66042
# [127]	eval-rmse:83.65179
# [128]	eval-rmse:83.65389
# [129]	eval-rmse:83.57266
# [130]	eval-rmse:83.58315
# [131]	eval-rmse:83.59453
# [132]	eval-rmse:83.59016
# [133]	eval-rmse:83.55060
# [134]	eval-rmse:83.53824
# [135]	eval-rmse:83.41944
# [136]	eval-rmse:83.40621
# [137]	eval-rmse:83.39661
# [138]	eval-rmse:83.40633
# [139]	eval-rmse:83.31229
# [140]	eval-rmse:83.30679
# [141]	eval-rmse:83.27263
# [142]	eval-rmse:83.27464
# [143]	eval-rmse:83.26620
# [144]	eval-rmse:83.24202
# [145]	eval-rmse:83.24976
# [146]	eval-rmse:83.23693
# [147]	eval-rmse:83.18364
# [148]	eval-rmse:83.21567
# [149]	eval-rmse:83.21827
# [150]	eval-rmse:83.21940
# [151]	eval-rmse:83.19915
# [152]	eval-rmse:83.19637
# [153]	eval-rmse:83.19772
# [154]	eval-rmse:83.10043
# [155]	eval-rmse:83.10279
# [156]	eval-rmse:83.06138
# [157]	eval-rmse:83.04811
# [158]	eval-rmse:83.05904
# [159]	eval-rmse:83.06204
# [160]	eval-rmse:83.03076
# [161]	eval-rmse:83.01753
# [162]	eval-rmse:83.02403
# [163]	eval-rmse:83.02364
# [164]	eval-rmse:83.03151
# [165]	eval-rmse:83.02917
# [166]	eval-rmse:83.01748
# [167]	eval-rmse:83.00366
# [168]	eval-rmse:82.98208
# [169]	eval-rmse:82.99162
# [170]	eval-rmse:82.97235
# [171]	eval-rmse:82.91690
# [172]	eval-rmse:82.91310
# [173]	eval-rmse:82.92901
# [174]	eval-rmse:82.90105
# [175]	eval-rmse:82.89973
# [176]	eval-rmse:82.90533
# [177]	eval-rmse:82.90496
# [178]	eval-rmse:82.95190
# [179]	eval-rmse:82.93831
# [180]	eval-rmse:82.90970
# [181]	eval-rmse:82.90485
# [182]	eval-rmse:82.90344
# [183]	eval-rmse:82.88277
# [184]	eval-rmse:82.88753
# [185]	eval-rmse:82.87573
# [186]	eval-rmse:82.85344
# [187]	eval-rmse:82.84998
# [188]	eval-rmse:82.83768
# [189]	eval-rmse:82.83268
# [190]	eval-rmse:82.83634
# [191]	eval-rmse:82.85244
# [192]	eval-rmse:82.83928
# [193]	eval-rmse:82.83977
# [194]	eval-rmse:82.82832
# [195]	eval-rmse:82.81415
# [196]	eval-rmse:82.78661
# [197]	eval-rmse:82.79028
# [198]	eval-rmse:82.78166
# [199]	eval-rmse:82.76870
# [200]	eval-rmse:82.79332
# [201]	eval-rmse:82.79540
# [202]	eval-rmse:82.80876
# [203]	eval-rmse:82.77515
# [204]	eval-rmse:82.79888
# [205]	eval-rmse:82.80750
# [206]	eval-rmse:82.79296
# [207]	eval-rmse:82.79391
# [208]	eval-rmse:82.77228
# [209]	eval-rmse:82.76121
# [210]	eval-rmse:82.76499
# [211]	eval-rmse:82.77486
# [212]	eval-rmse:82.75693
# [213]	eval-rmse:82.75385
# [214]	eval-rmse:82.75352
# [215]	eval-rmse:82.74841
# [216]	eval-rmse:82.73269
# [217]	eval-rmse:82.74781
# [218]	eval-rmse:82.72410
# [219]	eval-rmse:82.72385
# [220]	eval-rmse:82.71938
# [221]	eval-rmse:82.69886
# [222]	eval-rmse:82.69836
# [223]	eval-rmse:82.69528
# [224]	eval-rmse:82.69566
# [225]	eval-rmse:82.70484
# [226]	eval-rmse:82.63557
# [227]	eval-rmse:82.63357
# [228]	eval-rmse:82.63698
# [229]	eval-rmse:82.62693
# [230]	eval-rmse:82.65163
# [231]	eval-rmse:82.63955
# [232]	eval-rmse:82.65286
# [233]	eval-rmse:82.66660
# [234]	eval-rmse:82.68668
# [235]	eval-rmse:82.67048
# [236]	eval-rmse:82.64287
# [237]	eval-rmse:82.65894
# [238]	eval-rmse:82.67190
# [239]	eval-rmse:82.66446
# Stopping. Best iteration:
# [229]	eval-rmse:82.62693

# %% [markdown]
# ## RESULTS

# %%
y_true = np.array(y_test, dtype=np.float)
y_pred = np.array(model.predict(dtest), dtype=np.float)

# %%
r2 = r2_score(y_true, y_pred)
print("R^2 Score: {:.4f}".format(r2))
# Out:
# R^2 Score: 0.9408
